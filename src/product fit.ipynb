# %% [markdown]
# # Product Fit code

# %%
import pandas as pd
import numpy as np
import math

df = pd.read_csv("test_data.csv")
df.head()
# Out:
#      SKU_ID                          Description QTY_Stock UOM Length Width  \
# 0  10000059  DAD YOURE OUT OF THIS WORLD CUHSION         4  ea    500   350
# 1  10000117      C&B STRAW &# W CHOC CHUNK BISC#       647  ea    172    94
# 2  10000163          100 CRAFT BEERS BUCKET LIST       754  ea    470    90
# 3  10000188             PLAYMOBIL POLICE RANGERS       203  ea    348   248
# 4  10000205   LOVE HEARTS 18CM FRIES BEFORE GUYS        56  ea    180   174
#
#   Height Weight [kg]   File
# 0    130        0.48  Stock
# 1     94        0.42  Stock
# 2     80        0.14  Stock
# 3     99        0.52  Stock
# 4    150        0.11  Stock

# %% [markdown]
# ## Input the type of bin being used.

# %%
autostore_bin_type = input("Input the Bin type: \n") # can make this into an automation type selector so GEEK and t-Sort can be included

autoStore_bin_size = [3]
    
unit_type = input("What unit for calculation: ")
    #bin type switch
match autostore_bin_type:
    case "220":
            autoStore_bin_size = [220,400,600]
    case "330":
            autoStore_bin_size = [330,400,600]
    case "425":
            autoStore_bin_size = [425,400,600]
    case"geek":
            autoStore_bin_size = [573,240,315]
    case _:
            print("no bins type selected")
    #bin type switch
match unit_type:
        case "mm":
            print("is mm")
        case "cm":
            t = autoStore_bin_size
            autoStore_bin_size = [x/10 for x in autoStore_bin_size]
        case "m":
            t = autoStore_bin_size
            autoStore_bin_size = [x/1000 for x in autoStore_bin_size]  
            
        case _:
            print("no unit selected")

# %% [markdown]
# ### AS 220s

# %%
autoStore_bin_size = [220,400,600]

# %% [markdown]
# ### AS 330s

# %%
autoStore_bin_size = [330,400,600]

# %% [markdown]
# ### AS 425s

# %%
autoStore_bin_size = [425,400,600]

# %% [markdown]
# ### GEEK+ Rack location

# %%
autoStore_bin_size = [573,240,315]

# %% [markdown]
# GEEK racks have 25 locations per side so for an entire pod it is 25 * 2

# %% [markdown]
# ## Units

# %% [markdown]
# mm are default

# %% [markdown]
# ### CM

# %%
t = autoStore_bin_size
autoStore_bin_size = [x/10 for x in autoStore_bin_size]

# %% [markdown]
# ### M

# %%
t = autoStore_bin_size
autoStore_bin_size = [x/100 for x in autoStore_bin_size]
